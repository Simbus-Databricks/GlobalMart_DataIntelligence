# %%
# %sql
select *
from globalmart_dev.bronze.customers
limit 20

# %%
# %sql
select *
from globalmart_dev.bronze.customers
where `_rescued_data` is not null

# %%
df = spark.table("globalmart_dev.bronze.transactions")
# display(df)
for i in df.columns:
  print(i)

# %%
columns_mapping  = {"order_id":["order_id", "OrderId"],
                    "return_reason":["reason", "return_reason"],
                    "return_date":["return_date", "date_of_return"],
                    "refund_amount":["refund_amount", "amount"],
                    "return_status":["return_status", "status"]}

# %%
df = spark.sql("select distinct ship_mode from globalmart_dev.bronze.orders")
display(df)

# %%
# %sql
select count(*)
from globalmart_dev.bronze.transactions

# %%
# %sql
select *
from globalmart_dev.bronze.transactions

# %%
# %sql
drop table globalmart_dev.bronze.customers_silver

# %%
# %sql
select * from globalmart_dev.silver.returns_silver
where `_rescued_data` is not null

# %%
# %sql
select count(*)
from globalmart_dev.bronze.returns_silver
where return_reason is null

# %%
# %sql
drop table globalmart_dev.bronze.customers_quarantine;

# %%
# %sql
select *
from globalmart_dev.silver.products_silver

# %%
# %sql
select *

from globalmart_dev.silver.customers_quarantine

# %%
# %sql
select count(*)
from globalmart_dev.silver.customers_quarantine

# %%
# %sql
select *
from globalmart_dev.silver.customers_quarantine
where customer_email is not null

# %%
# %sql
select * from globalmart_dev.silver.orders_quarantine

# %%
# %sql
select *
from globalmart_dev.silver.orders_quarantine
where ("order_id", "customer_id", "vendor_id") is null

# %%
# %sql
select count(*)
from globalmart_dev.silver.orders_quarantine
where "order_id" is null

# %%
# %sql
select count(*)
from globalmart_dev.silver.orders_quarantine
where "customer_id" is null

# %%
# %sql
select count(*)
from globalmart_dev.silver.orders_quarantine
where "vendor_id" is null

# %%
# %sql
select * from globalmart_dev.silver.orders_quarantine

# %%
# %sql
select * from globalmart_dev.silver.orders_silver

# %%
# %sql
select * from globalmart_dev.silver.orders_quarantine
where order_purchase_date is m

# %%
# %sql
select * from globalmart_dev.silver.products_silver

# %%
# %sql
select * from globalmart_dev.silver.returns_silver

# %%
# %sql
select * from globalmart_dev.bronze.returns

# %%
# %sql
select *
from globalmart_dev.silver.returns_silver 
-- where order_id is null

# %%
# %sql
select *
from globalmart_dev.silver.returns_quarantine

# %%
# %sql
select * from globalmart_dev.silver.transactions_quarantine
where `_rescued_data` is not null

# %%
# %sql
select *
from globalmart_dev.silver.returns_silver

# %%
# %sql
select * from globalmart_dev.silver.transactions_silver

# %%
# %sql
select count(*) from globalmart_dev.bronze.transactions

# %%
# %sql
select count(*)
from globalmart_dev.silver.transactions_quarantine

# %%
# %sql
select count(*)
from globalmart_dev.silver.transactions_silver

# %%
df_gold_fact_return = spark.read.table("globalmart_dev.bronze.gold_fact_returns")
display(df_gold_fact_return)
